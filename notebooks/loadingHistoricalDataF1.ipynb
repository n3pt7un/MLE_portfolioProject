# %%
import pandas as pd 
import numpy as np 
import os

data = '../data/HistoricalData/'

# %%
dataframes = []
for file_name in os.listdir(data):
    if file_name.endswith('.csv'):  # Ensure it is a CSV file
        # Extract the name without the ".csv" extension
        variable_name = file_name[:-4]
        dataframes.append(variable_name)
        # Load the CSV into a variable dynamically
        globals()[variable_name] = pd.read_csv(f"{data}{file_name}")
dataframes
# Out:
# ['circuits',
#  'constructors',
#  'constructor_results',
#  'constructor_standings',
#  'drivers',
#  'driver_standings',
#  'lap_times',
#  'pit_stops',
#  'qualifying',
#  'races',
#  'results',
#  'seasons',
#  'sprint_results',
#  'status']

# %%
constructors
# Out:
#      constructorId constructorRef            name nationality  \
# 0                1        mclaren         McLaren     British
# 1                2     bmw_sauber      BMW Sauber      German
# 2                3       williams        Williams     British
# 3                4        renault         Renault      French
# 4                5     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 207            210           haas    Haas F1 Team    American
# 208            211   racing_point    Racing Point     British
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
# 211            215             rb      RB F1 Team     Italian
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren
# 1              http://en.wikipedia.org/wiki/BMW_Sauber
# ...
